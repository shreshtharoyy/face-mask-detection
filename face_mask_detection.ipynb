# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
uploaded = drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

zip_path = '/content/drive/MyDrive/CV/Face_Mask_Detection/Face Mask.v1i.yolov8.zip'

with zipfile.ZipFile (zip_path, 'r') as zip_ref:
  zip_ref.extractall('content/data/Drive')

# %%
model = YOLO('yolov8s.pt')

# %%
model.train(data='/content/drive/MyDrive/CV/Face_Mask_Detection/Face Mask.v1i.yolov8.zip', epochs=50, imgsz=640, batch=16)
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 476.9±129.3 MB/s, size: 19.6 KB)
# val: Scanning /content/datasets/Face Mask.v1i.yolov8/valid/labels.cache... 806 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 806/806 339.1Kit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 4, len(boxes) = 1255. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 4.0it/s 12.8s
#                    all        806       1255       0.83       0.74      0.808      0.564
#         incorrect_mask         48         52      0.753      0.615      0.696      0.467
# ...

# %%
from ultralytics import YOLO

model1 = YOLO('/content/runs/detect/train/weights/best.pt')
metrics1 = model1.val()
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 704.0±500.7 MB/s, size: 23.0 KB)
# val: Scanning /content/datasets/Face Mask.v1i.yolov8/valid/labels.cache... 806 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 806/806 1.3Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 4, len(boxes) = 1255. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 51/51 4.0it/s 12.7s
#                    all        806       1255       0.83       0.74      0.808      0.564
#         incorrect_mask         48         52      0.753      0.615      0.696      0.467
# ...
